# %%
number_list = [10,100,1000,10000,101]


print (f"first number {number_list[0]}")
print (f"second number {number_list[1]}")
print (f"third number {number_list[2]}")
print (f"fourth number {number_list[3]}")
print (f"fifth number {number_list[4]}")
number_list.append(120)


#reverse list
print (f"sixth number {number_list[5]}")
number_list.reverse()

print (number_list)
print (f"first number {number_list[0]}")

# count occurences


numbers = [1,2,2,1,8,4,6,9,8,3,2,5,7,0]
user_input = int(input("search for number"))
count = numbers.count(user_input)
print(count)



#to append the items of list 1 to list 2 in the front

number_list = numbers + number_list
print(numbers)
print(number_list)


#to insert item at specific 

numbers.insert(3,121)
print(numbers)
# Out:
# first number 10
# second number 100
# third number 1000
# fourth number 10000
# fifth number 101
# sixth number 120
# [120, 101, 10000, 1000, 100, 10]
# first number 120
# search for number 23
# 0
# [1, 2, 2, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0]
# [1, 2, 2, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0, 120, 101, 10000, 1000, 100, 10]
# [1, 2, 2, 121, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0]

# %%
numbers = [1,2,2,1,8,4,6,9,8,3,2,5,7,0]


numbers.insert(3,121)
print(numbers)
# Out:
# [1, 2, 2, 121, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0]

# %%
numbers = [1,2,2,1,8,4,6,9,8,3,2,5,7,0]
usr = int(input("enter index to remove"))
numbers.pop(usr)

print(numbers)
# Out:
# enter index to remove 2
# [1, 2, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0]

# %%
numbers = [1,2,2,1,8,4,6,9,8,3,2,5,7,0]
usr = int(input("enter number to remove:"))
numbers.remove(usr)

print(numbers)
# Out:
# enter number to remove: 2
# [1, 2, 1, 8, 4, 6, 9, 8, 3, 2, 5, 7, 0]
