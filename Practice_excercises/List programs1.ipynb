# %%
#program to print strings

S_name = input("enter a name:")
s_adress = input("adress:")
s_phone = int(input("Phone number:"))
S_mother_tongue = input("mother tongue")

s_school_name = input("school name")
s_year = int(input("year"))
s_panel = input("panel")
s_roll_no = int(input("rollno"))

print("\n"*5)
print(S_name)
print(s_adress)
print(s_phone)
print(S_mother_tongue)
print(s_school_name)


print(s_year)
print(s_panel)
print(s_roll_no)
# Out:
# enter a name: 121
# adress: 121
# Phone number: 12
# mother tongue 12
# school name 121
# year 21
# panel 2121
# rollno 12
# 121
# 121
# 12
# 12
# 121
# 21
# 2121
# 12

# %%
s_name = input("name:")
s_roll = int(input("roll no:"))
s_m = float(input("enter your mathematics marks"))
s_p = float(input("enter your physics marks"))
s_c = float(input("enter your chemistry marks"))


percentage =( s_m+s_p+s_c)/3
print(f"the percentage is {percentage}")

if s_m >= s_p and s_c:
    print(f"highest Marks are  {s_m}")
elif s_p >= s_m and s_c:
    print(f"highest Marks are {s_p}")
else:
    print(f"highest Marks are   {s_c}")
# Out:
# name: pos
# roll no: 12
# enter your mathematics marks 12
# enter your physics marks 15
# enter your chemistry marks 14
# the percentage is 13.666666666666666
# highest Marks are 15.0

# %% [markdown]
# for i  in range(5):
#     number = int(input("enter a number to cube:"))
#     cube = number**3
#     print(f"the cube of {number} is : {cube}")

# %%
for i  in range(5):
    number = int(input("enter a number to cube:"))
    cube = number**3
    print(f"the cube of {number} is : {cube}")
# Out:
# enter a number to cube: 12
# the cube of 12 is : 1728
# enter a number to cube: 1
# the cube of 1 is : 1
# enter a number to cube: 11
# the cube of 11 is : 1331
# enter a number to cube: 12
# the cube of 12 is : 1728
# enter a number to cube: 12
# the cube of 12 is : 1728

# %%
print(45//10)
# Out:
# 4

# %%
number = int(input("enter a number:"))
reverse = 0
while number>0:
    digit = number % 10
    reverse = reverse + digit *10
    number = number//10
print(rev_nums)

# %%
number = int(input("enter a number:"))
reverse = 0
while number>0:
    digit = number % 10
    reverse = reverse*10 + digit 
    number = number//10
    reverse = reverse + number
print(reverse)
# Out:
# enter a number: 12
# 31

# %%
year = input("enter the year you wanna check:")

if year% 400 == 0
