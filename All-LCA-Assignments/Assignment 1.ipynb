# %%
my_list = [1,2,3,4]
print(my_list[0])

my_list.append(12)
print(my_list)

my_list.remove(1)
print(my_list)

my_tupple = (18,19,32)
print(my_tupple)

my_dictionary = {
    '12' : "twelve" , 
    '13' : "thirteen"
    

}


print(my_dictionary)

print(my_dictionary ['12'])

my_dictionary['12'] : "sixteen"
print(my_dictionary)

del my_dictionary ['12']

print(my_dictionary)
# Out:
# 1
# [1, 2, 3, 4, 12]
# [2, 3, 4, 12]
# (18, 19, 32)
# {'12': 'twelve', '13': 'thirteen'}
# twelve
# {'12': 'twelve', '13': 'thirteen'}
# {'13': 'thirteen'}

# %%
my_dictionary = {
    '12' : "twelve" , 
    '13' : "thirteen"
    

}
print(my_dictionary)
my_dictionary['12'] = "sixteen"
print(my_dictionary)
# Out:
# {'12': 'twelve', '13': 'thirteen'}
# {'12': 'sixteen', '13': 'thirteen'}
